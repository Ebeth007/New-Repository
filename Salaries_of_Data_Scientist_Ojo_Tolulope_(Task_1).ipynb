# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebeth007/New-Repository/blob/main/Salaries_of_Data_Scientist_Ojo_Tolulope_(Task_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
data=pd.read_csv('/content/ds_salaries.csv')
data.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
data.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
data.duplicated().sum()
# Out:
# 0

# %%
#1a Univariate Analysis for the Categorical features

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
plt.title('	experience_level')
sns.countplot(x='experience_level',data=data);
plt.xlabel('experience_level')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(120,50))
plt.title('job_title')
sns.countplot(x='job_title',data=data);
plt.xlabel('job_title')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title('employment_type')
sns.countplot(x='employment_type',data=data);
plt.xlabel('employment_type')
plt.show()

# %%
plt.figure(figsize=(50,30))
plt.title('employee_residence')
sns.countplot(x='employee_residence',data=data);
plt.xlabel('employee_residence')
plt.show()

# %%
plt.figure(figsize=(30,20))
plt.title('company_location')
sns.countplot(x='company_location',data=data);
plt.xlabel('company_location')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title('company_size')
sns.countplot(x='company_size',data=data);
plt.xlabel('company_size')
plt.show()

# %%
#1b Univariate Analysis for the Numerical features

# %%
plt.figure(figsize=(8,6))
plt.title('work_year')
sns.countplot(x='work_year',data=data);
plt.xlabel('work_year')
plt.show()

# %%
sns.distplot(data['salary_in_usd']);
# Out:
# <ipython-input-57-f2298cb4116d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['salary_in_usd']);

# %%
sns.distplot(data['remote_ratio']);
# Out:
# <ipython-input-58-048434a88829>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['remote_ratio']);

# %%
 #2 Work Year Analysis

# %%
#Remote Ratio by Work Year

plt.figure(figsize=(6,8))
plt.title('Remote Ratio by work year')
sns.barplot(x='work_year',y='remote_ratio',data=data);
plt.xlabel('work_year')
plt.ylabel('remote_ratio')
plt.show()

# %%
#3 Experience Level Analysis

# %%
# - Employment Type by Experience 

# read csv using pandas
import pandas as pd
data = pd.read_csv('/content/ds_salaries.csv')

# cross tab of employment_type and experience_level
pd.crosstab(index=data['employment_type'], columns=data['experience_level'])
# Out:
# experience_level  EN  EX   MI   SE
# employment_type
# CT                 2   1    1    1
# FL                 0   0    3    1
# FT                79  25  206  278
# PT                 7   0    3    0

# %%
#Top 3 Job Title by Experience Level

# %%
# read csv using pandas
import pandas as pd
data = pd.read_csv('/content/ds_salaries.csv')

# cross tab of job and experience_level
pd.crosstab(index=data['job_title'], columns=data['experience_level'])
# Out:
# experience_level                          EN  EX  MI  SE
# job_title
# 3D Computer Vision Researcher              0   0   1   0
# AI Scientist                               4   0   2   1
# Analytics Engineer                         0   2   0   2
# Applied Data Scientist                     1   0   2   2
# Applied Machine Learning Scientist         1   0   3   0
# BI Data Analyst                            2   1   3   0
# Big Data Architect                         0   0   0   1
# Big Data Engineer                          3   0   3   2
# Business Data Analyst                      2   0   3   0
# Cloud Data Engineer                        0   0   1   1
# Computer Vision Engineer                   3   0   0   3
# Computer Vision Software Engineer          2   0   1   0
# Data Analyst                              12   2  29  54
# Data Analytics Engineer                    1   0   1   2
# Data Analytics Lead                        0   0   0   1
# ...

# %%
# Company size by experience level
# read csv using pandas
import pandas as pd
data = pd.read_csv('/content/ds_salaries.csv')

# cross tab of employment_type and experience_level
pd.crosstab(index=data['company_size'], columns=data['experience_level'])
# Out:
# experience_level  EN  EX  MI   SE
# company_size
# L                 29  11  86   72
# M                 30  12  98  186
# S                 29   3  29   22

# %%
#4 Company Location Analysis

# %%
#Experience Level

plt.figure(figsize=(6,8))
plt.title('experience_level')
sns.countplot(x='experience_level',data=data);
plt.xlabel('experience_level')
plt.show()

# %%
#5 Salary Analysis
#Bivariate Analysis

# %%
#Salary by work year

plt.figure(figsize=(6,8))
plt.title('Salary by work year')
sns.barplot(x='work_year',y='salary',data=data);
plt.xlabel('work_year')
plt.ylabel('salary')
plt.show()

# %%
#Salary by Experience Level

plt.figure(figsize=(10,8))
plt.title('Salary by experience level')
sns.barplot(x='experience_level',y='salary',data=data);
plt.xlabel('experience_level')
plt.ylabel('salary')
plt.show()

# %%
#Salary by Company Size

plt.figure(figsize=(10,8))
plt.title('Salary by company size')
sns.barplot(x='company_size',y='salary',data=data);
plt.xlabel('company_size')
plt.ylabel('salary')
plt.show()

# %%
#Highest salaries by job title

plt.figure(figsize=(100,50))
plt.title('Highest salaries by job title')
sns.barplot(x='job_title',y='salary',data=data);
plt.xlabel('job_title')
plt.ylabel('salary')
plt.show()

# %%
#Average Salary by Company Location

plt.figure(figsize=(100,30))
plt.title('Average Salary by Company Location')
sns.barplot(x='company_location',y='salary',data=data);
plt.xlabel('company_location')
plt.ylabel('salary')
plt.show()
